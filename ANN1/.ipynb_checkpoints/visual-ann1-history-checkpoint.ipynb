# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
# %ls
# Out:
# ann1.h5                    ann1_history.csv
# ann1.py                    ann1_res.txt
# ann1_acc_loss.png          validation.csv
# ann1_auc.png               visual-ann1-history.ipynb

# %%
h = pd.read_csv("ann1_history.csv")

# %%
h.head()
# Out:
#        loss  accuracy       auc  val_loss  val_accuracy   val_auc
# 0  0.349467  0.853663  0.923502  0.266824      0.889246  0.955008
# 1  0.238492  0.902029  0.963646  0.203668      0.917581  0.974362
# 2  0.185225  0.926878  0.977905  0.160814      0.937944  0.984018
# 3  0.148945  0.943986  0.985062  0.132701      0.951053  0.988703
# 4  0.126002  0.953489  0.988757  0.115774      0.957448  0.990360

# %%
plt.figure(figsize=(10, 10))
plt.subplot(2,1,1)
plt.plot(h['loss'], color='blue', marker='o', label='training')
plt.plot(h['val_loss'], color='red', marker='o', label='validation')
plt.legend(fontsize=14)
plt.title("Loss curves",fontsize=14)
plt.ylabel("Binary Crossentropy",fontsize=14)
plt.xlabel("Epoch",fontsize=14)
#plt.show()


plt.figure(figsize=(10, 10))
plt.subplot(2,1,2)
plt.plot(h['accuracy'], color='blue', marker='o', label='training')
plt.plot(h['val_accuracy'], color='red', marker='o', label='validation')
plt.legend(fontsize=14)
plt.title("Accuracy curves",fontsize=14)
plt.ylabel("Accuracy",fontsize=14)
plt.xlabel("Epoch",fontsize=14)
plt.show()

plt.savefig("ann1_acc_loss_curves.png")

# %%
plt.figure(figsize=(10, 7))
plt.plot(h['auc'], color='blue', marker='o', label='training')
plt.plot(h['val_auc'], color='red', marker='o', label='validation')
plt.legend(fontsize=14)
plt.title("AUC  Curves",fontsize=14)
plt.ylabel("AUC (Precision-Recall)", fontsize=14)
plt.xlabel("Epoch",fontsize=14)
# Out:
# Text(0.5, 0, 'Epoch')
